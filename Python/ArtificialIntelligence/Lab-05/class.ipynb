# %%
romania = {
    'Oradea':['Zerind','Sibiu'],
    'Zerind':['Arad', 'Oradea'],
    'Arad':['Zerind', 'Sibiu', 'Timisoara'],
    'Timisoara':['Lugoj', 'Arad'],
    'Lugoj':['Mehadia', 'Timisoara'],
    'Mehadia':['Drobeta', 'Lugoj'],
    'Drobeta':['Craiova', 'Mehadia'],
    'Craiova':['Drobeta', 'Rimnicu Vilcea','Pitesti'],
    'Sibiu':['Fagaras','Rimnicu Vilcea', 'Arad'],
    'Rimnicu Vilcea':['Sibiu', 'Pitesti', 'Craiova'],
    'Fagaras':['Sibiu', 'Bucharest'],
    'Pitesti':['Rimnicu Vilcea', 'Craiova', 'Bucharest'],
    'Bucharest':['Fagaras','Pitesti', 'Giurgiu', 'Urziceni'],
    'Giurgiu':['Bucharest'],
    'Urziceni':['Hirsova', 'Bucharest', 'Vaslui'],
    'Hirsova': ['Urziceni', 'Eforie'],
    'Eforie':['Hirsova'],
    'Vaslui':['Urziceni', 'Lasi'],
    'Lasi':['Vaslui', 'Neamt'],
    'Neamt':['Lasi']
    
}

visited = [] 
queue = []     

def bfs(visited, graph, node): 
  visited.append(node)
  queue.append(node)

  while queue:          
    m = queue.pop(0) 
    print (m, end = "\n") 

    for neighbour in graph[m]:
      if neighbour not in visited:
        visited.append(neighbour)
        queue.append(neighbour)



bfs(visited, romania, 'Oradea')
# Out:
# Oradea
# Zerind
# Sibiu
# Arad
# Fagaras
# Rimnicu Vilcea
# Timisoara
# Bucharest
# Pitesti
# Craiova
# Lugoj
# Giurgiu
# Urziceni
# Drobeta
# Mehadia
# Hirsova
# Vaslui
# Eforie
# Lasi
# Neamt

# %%
romania = {
    'Oradea':['Zerind','Sibiu'],
    'Zerind':['Arad', 'Oradea'],
    'Arad':['Zerind', 'Sibiu', 'Timisoara'],
    'Timisoara':['Lugoj', 'Arad'],
    'Lugoj':['Mehadia', 'Timisoara'],
    'Mehadia':['Drobeta', 'Lugoj'],
    'Drobeta':['Craiova', 'Mehadia'],
    'Craiova':['Drobeta', 'Rimnicu Vilcea','Pitesti'],
    'Sibiu':['Fagaras','Rimnicu Vilcea', 'Arad'],
    'Rimnicu Vilcea':['Sibiu', 'Pitesti', 'Craiova'],
    'Fagaras':['Sibiu', 'Bucharest'],
    'Pitesti':['Rimnicu Vilcea', 'Craiova', 'Bucharest'],
    'Bucharest':['Fagaras','Pitesti', 'Giurgiu', 'Urziceni'],
    'Giurgiu':['Bucharest'],
    'Urziceni':['Hirsova', 'Bucharest', 'Vaslui'],
    'Hirsova': ['Urziceni', 'Eforie'],
    'Eforie':['Hirsova'],
    'Vaslui':['Urziceni', 'Lasi'],
    'Lasi':['Vaslui', 'Neamt'],
    'Neamt':['Lasi']
    
}

visited = set()

def dfs(visited, graph, node):
    if node not in visited:
        print (node)
        visited.add(node)
        for neighbour in graph[node]:
            dfs(visited, graph, neighbour)


print("Following is the Depth-First Search")
dfs(visited, romania, 'Oradea')
# Out:
# Following is the Depth-First Search
# Oradea
# Zerind
# Arad
# Sibiu
# Fagaras
# Bucharest
# Pitesti
# Rimnicu Vilcea
# Craiova
# Drobeta
# Mehadia
# Lugoj
# Timisoara
# Giurgiu
# Urziceni
# Hirsova
# Eforie
# Vaslui
# Lasi
# Neamt

# %%
romania = {
    'Oradea':['Zerind','Sibiu'],
    'Zerind':['Arad', 'Oradea'],
    'Arad':['Zerind', 'Sibiu', 'Timisoara'],
    'Timisoara':['Lugoj', 'Arad'],
    'Lugoj':['Mehadia', 'Timisoara'],
    'Mehadia':['Drobeta', 'Lugoj'],
    'Drobeta':['Craiova', 'Mehadia'],
    'Craiova':['Drobeta', 'Rimnicu Vilcea','Pitesti'],
    'Sibiu':['Fagaras','Rimnicu Vilcea', 'Arad'],
    'Rimnicu Vilcea':['Sibiu', 'Pitesti', 'Craiova'],
    'Fagaras':['Sibiu', 'Bucharest'],
    'Pitesti':['Rimnicu Vilcea', 'Craiova', 'Bucharest'],
    'Bucharest':['Fagaras','Pitesti', 'Giurgiu', 'Urziceni'],
    'Giurgiu':['Bucharest'],
    'Urziceni':['Hirsova', 'Bucharest', 'Vaslui'],
    'Hirsova': ['Urziceni', 'Eforie'],
    'Eforie':['Hirsova'],
    'Vaslui':['Urziceni', 'Lasi'],
    'Lasi':['Vaslui', 'Neamt'],
    'Neamt':['Lasi']
    
}

visited = set()

def dfs(visited, graph, node):
    print("Visited= " , visited, " Node= ", node)
    if node not in visited:
        print (node)
        visited.add(node)
        for neighbour in graph[node]:
            dfs(visited, graph, neighbour)


print("Following is the Depth-First Search")
dfs(visited, romania, 'Oradea')
# Out:
# Following is the Depth-First Search
# Visited=  set()  Node=  Oradea
# Oradea
# Visited=  {'Oradea'}  Node=  Zerind
# Zerind
# Visited=  {'Zerind', 'Oradea'}  Node=  Arad
# Arad
# Visited=  {'Arad', 'Zerind', 'Oradea'}  Node=  Zerind
# Visited=  {'Arad', 'Zerind', 'Oradea'}  Node=  Sibiu
# Sibiu
# Visited=  {'Arad', 'Sibiu', 'Zerind', 'Oradea'}  Node=  Fagaras
# Fagaras
# Visited=  {'Arad', 'Sibiu', 'Zerind', 'Oradea', 'Fagaras'}  Node=  Sibiu
# Visited=  {'Arad', 'Sibiu', 'Zerind', 'Oradea', 'Fagaras'}  Node=  Bucharest
# Bucharest
# Visited=  {'Arad', 'Sibiu', 'Zerind', 'Bucharest', 'Oradea', 'Fagaras'}  Node=  Fagaras
# Visited=  {'Arad', 'Sibiu', 'Zerind', 'Bucharest', 'Oradea', 'Fagaras'}  Node=  Pitesti
# Pitesti
# Visited=  {'Arad', 'Sibiu', 'Zerind', 'Bucharest', 'Pitesti', 'Oradea', 'Fagaras'}  Node=  Rimnicu Vilcea
# Rimnicu Vilcea
# Visited=  {'Arad', 'Sibiu', 'Zerind', 'Bucharest', 'Pitesti', 'Rimnicu Vilcea', 'Oradea', 'Fagaras'}  Node=  Sibiu
# ...
